# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"X:\CODING\Statistical Learning Lab\Assignemnt1\food_coded.csv")
df.head()
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.4       2          1               430           NaN           315.0
# 1  3.654       1          1               610           3.0           420.0
# 2    3.3       1          1               720           4.0           420.0
# 3    3.2       1          1               430           3.0           420.0
# 4    3.5       1          1               720           2.0           420.0
#
#    coffee                      comfort_food        comfort_food_reasons  \
# 0       1                              none       we dont have comfort
# 1       2       chocolate, chips, ice cream        Stress, bored, anger
# 2       2   frozen yogurt, pizza, fast food             stress, sadness
# 3       2  Pizza, Mac and cheese, ice cream                     Boredom
# 4       2      Ice cream, chocolate, chips   Stress, boredom, cravings
#
#    comfort_food_reasons_coded  ...  soup  sports  thai_food tortilla_calories  \
# 0                         9.0  ...   1.0     1.0          1            1165.0
# 1                         1.0  ...   1.0     1.0          2             725.0
# 2                         1.0  ...   1.0     2.0          5            1165.0
# 3                         2.0  ...   1.0     2.0          5             725.0
# 4                         1.0  ...   1.0     1.0          4             940.0
#
#    turkey_calories  type_sports veggies_day  vitamins  waffle_calories  \
# 0              345   car racing           5         1             1315
# 1              690  Basketball            4         2              900
# 2              500         none           5         1              900
# 3              690          NaN           3         1             1315
# 4              500     Softball           4         2              760
#
#                      weight
# 0                       187
# 1                       155
# 2  I'm not answering this.
# 3             Not sure, 240
# 4                       190
#
# [5 rows x 61 columns]

# %%
print(f"number of observations:{df.shape[0]}")
print(f"number of variables:{df.shape[1]}")
# Out:
# number of observations:125
# number of variables:61

# %%
print(df.dtypes)
# Out:
# GPA                  object
# Gender                int64
# breakfast             int64
# calories_chicken      int64
# calories_day        float64
#                      ...
# type_sports          object
# veggies_day           int64
# vitamins              int64
# waffle_calories       int64
# weight               object
# Length: 61, dtype: object

# %%
df.dtypes.value_counts()
# Out:
# int64      27
# float64    20
# object     14
# Name: count, dtype: int64

# %%
df.select_dtypes(include="number").isnull().sum()
# Out:
# Gender                           0
# breakfast                        0
# calories_chicken                 0
# calories_day                    19
# calories_scone                   1
# coffee                           0
# comfort_food_reasons_coded      19
# cook                             3
# comfort_food_reasons_coded.1     0
# cuisine                         17
# diet_current_coded               0
# drink                            2
# eating_changes_coded             0
# eating_changes_coded1            0
# eating_out                       0
# employment                       9
# ethnic_food                      0
# exercise                        13
# father_education                 1
# fav_cuisine_coded                0
# fav_food                         2
# fries                            0
# fruit_day                        0
# grade_level                      0
# greek_food                       0
# healthy_feeling                  0
# ideal_diet_coded                 0
# income                           1
# indian_food                      0
# italian_food                     0
# life_rewarding                   1
# marital_status                   1
# mother_education                 3
# nutritional_check                0
# on_off_campus                    1
# parents_cook                     0
# pay_meal_out                     0
# persian_food                     1
# self_perception_weight           1
# soup                             1
# sports                           2
# thai_food                        0
# tortilla_calories                1
# turkey_calories                  0
# veggies_day                      0
# vitamins                         0
# waffle_calories                  0
# dtype: int64

# %%
df.select_dtypes(include="number").isnull().sum().sum()
# Out:
# np.int64(99)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.select_dtypes(include="object").columns
# Out:
# Index(['GPA', 'comfort_food', 'comfort_food_reasons', 'diet_current',
#        'eating_changes', 'father_profession', 'fav_cuisine', 'food_childhood',
#        'healthy_meal', 'ideal_diet', 'meals_dinner_friend',
#        'mother_profession', 'type_sports', 'weight'],
#       dtype='object')

# %%
for col in df.select_dtypes(include='object').columns:
    temp=pd.to_numeric(df[col],errors='coerce')
    conversion_rate=temp.notna().mean()
    if(conversion_rate>=0.9):
        df[col]=temp
        print(f"converted {col} to numeric with conversion ratio: {conversion_rate}")
    else:
        print(f"failed to convert {col} to numeric with converstion ratio: {conversion_rate}")
# Out:
# converted GPA to numeric with conversion ratio: 0.96
# failed to convert comfort_food to numeric with converstion ratio: 0.0
# failed to convert comfort_food_reasons to numeric with converstion ratio: 0.0
# failed to convert diet_current to numeric with converstion ratio: 0.0
# failed to convert eating_changes to numeric with converstion ratio: 0.0
# failed to convert father_profession to numeric with converstion ratio: 0.0
# failed to convert fav_cuisine to numeric with converstion ratio: 0.0
# failed to convert food_childhood to numeric with converstion ratio: 0.0
# failed to convert healthy_meal to numeric with converstion ratio: 0.0
# failed to convert ideal_diet to numeric with converstion ratio: 0.0
# failed to convert meals_dinner_friend to numeric with converstion ratio: 0.0
# failed to convert mother_profession to numeric with converstion ratio: 0.0
# failed to convert type_sports to numeric with converstion ratio: 0.0
# converted weight to numeric with conversion ratio: 0.96

# %%
for col in df.select_dtypes(include="number").columns:
    print(f"COLUMN: {col}")
    print(f"mean: {df[col].mean()}")
    print(f"median: {df[col].median()}")
    print(f"Variance: {df[col].var()}")
    print(f"Std: {df[col].std()}")
    print(f"quantiles: {df[col].quantile([0.25,0.50,0.75])}")
    print()
# Out:
# COLUMN: GPA
# mean: 3.4155583333333337
# median: 3.5
# Variance: 0.15220838312324936
# Std: 0.39013892797726474
# quantiles: 0.25    3.2
# 0.50    3.5
# 0.75    3.7
# Name: GPA, dtype: float64
#
# COLUMN: Gender
# mean: 1.392
# median: 1.0
# Variance: 0.24025806451612908
# Std: 0.4901612637858372
# quantiles: 0.25    1.0
# 0.50    1.0
# 0.75    2.0
# Name: Gender, dtype: float64
#
# COLUMN: breakfast
# mean: 1.112
# median: 1.0
# Variance: 0.10025806451612906
# Std: 0.3166355389341649
# quantiles: 0.25    1.0
# 0.50    1.0
# 0.75    1.0
# Name: breakfast, dtype: float64
#
# COLUMN: calories_chicken
# mean: 577.32
# median: 610.0
# Variance: 17217.154838709674
# Std: 131.2141563959837
# quantiles: 0.25    430.0
# 0.50    610.0
# 0.75    720.0
# Name: calories_chicken, dtype: float64
#
# COLUMN: calories_day
# mean: 3.0283018867924527
# median: 3.0
# Variance: 0.40871518418688224
# Std: 0.6393083639268943
# quantiles: 0.25    3.0
# 0.50    3.0
# 0.75    3.0
# Name: calories_day, dtype: float64
#
# COLUMN: calories_scone
# mean: 505.241935483871
# median: 420.0
# Variance: 53287.33936532914
# Std: 230.8405063357147
# quantiles: 0.25    420.0
# 0.50    420.0
# 0.75    420.0
# Name: calories_scone, dtype: float64
#
# COLUMN: coffee
# mean: 1.752
# median: 2.0
# Variance: 0.18799999999999997
# Std: 0.43358966777357594
# quantiles: 0.25    2.0
# 0.50    2.0
# 0.75    2.0
# Name: coffee, dtype: float64
#
# COLUMN: comfort_food_reasons_coded
# mean: 2.69811320754717
# median: 2.0
# Variance: 3.8889487870619934
# Std: 1.9720417812668152
# quantiles: 0.25    2.0
# 0.50    2.0
# 0.75    3.0
# Name: comfort_food_reasons_coded, dtype: float64
#
# COLUMN: cook
# mean: 2.7868852459016393
# median: 3.0
# Variance: 1.0781736892020048
# Std: 1.038351428564532
# quantiles: 0.25    2.0
# 0.50    3.0
# 0.75    3.0
# Name: cook, dtype: float64
#
# COLUMN: comfort_food_reasons_coded.1
# mean: 2.688
# median: 2.0
# Variance: 3.6518709677419356
# Std: 1.9109869093591236
# quantiles: 0.25    2.0
# 0.50    2.0
# 0.75    3.0
# Name: comfort_food_reasons_coded.1, dtype: float64
#
# COLUMN: cuisine
# mean: 1.3888888888888888
# median: 1.0
# Variance: 0.9501557632398754
# Std: 0.9747593360619201
# quantiles: 0.25    1.0
# 0.50    1.0
# 0.75    1.0
# Name: cuisine, dtype: float64
#
# COLUMN: diet_current_coded
# mean: 1.76
# median: 2.0
# Variance: 0.5870967741935484
# Std: 0.7662224051759048
# quantiles: 0.25    1.0
# 0.50    2.0
# 0.75    2.0
# Name: diet_current_coded, dtype: float64
#
# COLUMN: drink
# mean: 1.5609756097560976
# median: 2.0
# Variance: 0.24830067972810874
# Std: 0.4982977821826109
# quantiles: 0.25    1.0
# 0.50    2.0
# 0.75    2.0
# Name: drink, dtype: float64
#
# COLUMN: eating_changes_coded
# mean: 1.536
# median: 1.0
# Variance: 0.5732903225806452
# Std: 0.757159377265213
# quantiles: 0.25    1.0
# 0.50    1.0
# 0.75    2.0
# Name: eating_changes_coded, dtype: float64
#
# COLUMN: eating_changes_coded1
# mean: 4.552
# median: 4.0
# Variance: 6.491225806451611
# Std: 2.5477884147730188
# quantiles: 0.25    3.0
# 0.50    4.0
# 0.75    5.0
# Name: eating_changes_coded1, dtype: float64
#
# COLUMN: eating_out
# mean: 2.56
# median: 2.0
# Variance: 1.2967741935483872
# Std: 1.1387599367506689
# quantiles: 0.25    2.0
# 0.50    2.0
# 0.75    3.0
# Name: eating_out, dtype: float64
#
# COLUMN: employment
# mean: 2.4482758620689653
# median: 2.0
# Variance: 0.28425787106446776
# Std: 0.5331583920979466
# quantiles: 0.25    2.0
# 0.50    2.0
# 0.75    3.0
# Name: employment, dtype: float64
#
# COLUMN: ethnic_food
# mean: 3.744
# median: 4.0
# Variance: 1.3855483870967746
# Std: 1.177093193887712
# quantiles: 0.25    3.0
# 0.50    4.0
# 0.75    5.0
# Name: ethnic_food, dtype: float64
#
# COLUMN: exercise
# mean: 1.5892857142857142
# median: 1.0
# Variance: 0.4424066924066925
# Std: 0.665136596803012
# quantiles: 0.25    1.0
# 0.50    1.0
# 0.75    2.0
# Name: exercise, dtype: float64
#
# COLUMN: father_education
# mean: 3.4838709677419355
# median: 4.0
# Variance: 1.4550222921584057
# Std: 1.2062430485430395
# quantiles: 0.25    2.0
# 0.50    4.0
# 0.75    4.0
# Name: father_education, dtype: float64
#
# COLUMN: fav_cuisine_coded
# mean: 2.424
# median: 1.0
# Variance: 3.7945806451612913
# Std: 1.9479683378231
# quantiles: 0.25    1.0
# 0.50    1.0
# 0.75    4.0
# Name: fav_cuisine_coded, dtype: float64
#
# COLUMN: fav_food
# mean: 1.7154471544715446
# median: 1.0
# Variance: 0.8282020525123284
# Std: 0.9100560710815176
# quantiles: 0.25    1.0
# 0.50    1.0
# 0.75    3.0
# Name: fav_food, dtype: float64
#
# COLUMN: fries
# mean: 1.088
# median: 1.0
# Variance: 0.08090322580645162
# Std: 0.2844349236757885
# quantiles: 0.25    1.0
# 0.50    1.0
# 0.75    1.0
# Name: fries, dtype: float64
#
# COLUMN: fruit_day
# mean: 4.224
# median: 5.0
# Variance: 0.8526451612903226
# Std: 0.9233878715308765
# quantiles: 0.25    4.0
# 0.50    5.0
# 0.75    5.0
# Name: fruit_day, dtype: float64
#
# COLUMN: grade_level
# mean: 2.376
# median: 2.0
# Variance: 1.2849032258064514
# Std: 1.1335357188048603
# quantiles: 0.25    1.0
# 0.50    2.0
# 0.75    3.0
# Name: grade_level, dtype: float64
#
# COLUMN: greek_food
# mean: 3.488
# median: 4.0
# Variance: 1.864774193548387
# Std: 1.3655673522563385
# quantiles: 0.25    3.0
# 0.50    4.0
# 0.75    5.0
# Name: greek_food, dtype: float64
#
# COLUMN: healthy_feeling
# mean: 5.456
# median: 5.0
# Variance: 6.685548387096776
# Std: 2.5856427415822116
# quantiles: 0.25    3.0
# 0.50    5.0
# 0.75    8.0
# Name: healthy_feeling, dtype: float64
#
# COLUMN: ideal_diet_coded
# mean: 3.704
# median: 3.0
# Variance: 4.355225806451613
# Std: 2.086917776638939
# quantiles: 0.25    2.0
# 0.50    3.0
# 0.75    6.0
# Name: ideal_diet_coded, dtype: float64
#
# COLUMN: income
# mean: 4.532258064516129
# median: 5.0
# Variance: 2.1209021767637037
# Std: 1.4563317536755502
# quantiles: 0.25    4.0
# 0.50    5.0
# 0.75    6.0
# Name: income, dtype: float64
#
# COLUMN: indian_food
# mean: 3.152
# median: 3.0
# Variance: 2.21058064516129
# Std: 1.4868021540074825
# quantiles: 0.25    2.0
# 0.50    3.0
# 0.75    5.0
# Name: indian_food, dtype: float64
#
# COLUMN: italian_food
# mean: 4.728
# median: 5.0
# Variance: 0.34477419354838723
# Std: 0.5871747555441967
# quantiles: 0.25    5.0
# 0.50    5.0
# 0.75    5.0
# Name: italian_food, dtype: float64
#
# COLUMN: life_rewarding
# mean: 5.104838709677419
# median: 5.0
# Variance: 9.736886965643851
# Std: 3.1203985267340215
# quantiles: 0.25    2.0
# 0.50    5.0
# 0.75    8.0
# Name: life_rewarding, dtype: float64
#
# COLUMN: marital_status
# mean: 1.5
# median: 1.0
# Variance: 0.3008130081300813
# Std: 0.5484642268462742
# quantiles: 0.25    1.0
# 0.50    1.0
# 0.75    2.0
# Name: marital_status, dtype: float64
#
# COLUMN: mother_education
# mean: 3.4262295081967213
# median: 4.0
# Variance: 1.3705459964774416
# Std: 1.170703205973846
# quantiles: 0.25    2.0
# 0.50    4.0
# 0.75    4.0
# Name: mother_education, dtype: float64
#
# COLUMN: nutritional_check
# mean: 3.152
# median: 3.0
# Variance: 1.4525161290322577
# Std: 1.2052037707509289
# quantiles: 0.25    2.0
# 0.50    3.0
# 0.75    4.0
# Name: nutritional_check, dtype: float64
#
# COLUMN: on_off_campus
# mean: 1.3225806451612903
# median: 1.0
# Variance: 0.4642014162077105
# Std: 0.6813232831833288
# quantiles: 0.25    1.0
# 0.50    1.0
# 0.75    1.0
# Name: on_off_campus, dtype: float64
#
# COLUMN: parents_cook
# mean: 1.528
# median: 1.0
# Variance: 0.5576774193548388
# Std: 0.7467780254900641
# quantiles: 0.25    1.0
# 0.50    1.0
# 0.75    2.0
# Name: parents_cook, dtype: float64
#
# COLUMN: pay_meal_out
# mean: 3.408
# median: 3.0
# Variance: 1.0821935483870964
# Std: 1.0402853206630844
# quantiles: 0.25    3.0
# 0.50    3.0
# 0.75    4.0
# Name: pay_meal_out, dtype: float64
#
# COLUMN: persian_food
# mean: 2.806451612903226
# median: 3.0
# Variance: 2.027275111460792
# Std: 1.4238241153530138
# quantiles: 0.25    2.0
# 0.50    3.0
# 0.75    4.0
# Name: persian_food, dtype: float64
#
# COLUMN: self_perception_weight
# mean: 3.120967741935484
# median: 3.0
# Variance: 1.2454104379753481
# Std: 1.1159795867198234
# quantiles: 0.25    2.0
# 0.50    3.0
# 0.75    4.0
# Name: self_perception_weight, dtype: float64
#
# COLUMN: soup
# mean: 1.217741935483871
# median: 1.0
# Variance: 0.17171518489378446
# Std: 0.4143853096983343
# quantiles: 0.25    1.0
# 0.50    1.0
# 0.75    1.0
# Name: soup, dtype: float64
#
# COLUMN: sports
# mean: 1.3902439024390243
# median: 1.0
# Variance: 0.23990403838464602
# Std: 0.48979999835100657
# quantiles: 0.25    1.0
# 0.50    1.0
# 0.75    2.0
# Name: sports, dtype: float64
#
# COLUMN: thai_food
# mean: 3.336
# median: 3.0
# Variance: 2.063612903225807
# Std: 1.4365280725505531
# quantiles: 0.25    2.0
# 0.50    3.0
# 0.75    5.0
# Name: thai_food, dtype: float64
#
# COLUMN: tortilla_calories
# mean: 947.5806451612904
# median: 940.0
# Variance: 40840.44059795436
# Std: 202.09017937038493
# quantiles: 0.25     725.0
# 0.50     940.0
# 0.75    1165.0
# Name: tortilla_calories, dtype: float64
#
# COLUMN: turkey_calories
# mean: 555.04
# median: 500.0
# Variance: 23216.732258064516
# Std: 152.37037854538696
# quantiles: 0.25    500.0
# 0.50    500.0
# 0.75    690.0
# Name: turkey_calories, dtype: float64
#
# COLUMN: veggies_day
# mean: 4.008
# median: 4.0
# Variance: 1.169290322580645
# Std: 1.0813372843755296
# quantiles: 0.25    3.0
# 0.50    4.0
# 0.75    5.0
# Name: veggies_day, dtype: float64
#
# COLUMN: vitamins
# mean: 1.512
# median: 2.0
# Variance: 0.25187096774193546
# Std: 0.5018674802594162
# quantiles: 0.25    1.0
# 0.50    2.0
# 0.75    2.0
# Name: vitamins, dtype: float64
#
# COLUMN: waffle_calories
# mean: 1073.4
# median: 900.0
# Variance: 61835.32258064515
# Std: 248.667091873141
# quantiles: 0.25     900.0
# 0.50     900.0
# 0.75    1315.0
# Name: waffle_calories, dtype: float64
#
# COLUMN: weight
# mean: 158.5
# median: 155.0
# Variance: 1008.5882352941177
# Std: 31.75827821677551
# quantiles: 0.25    135.0
# 0.50    155.0
# 0.75    180.0
# Name: weight, dtype: float64

# %%
df.describe()
# Out:
#               GPA      Gender   breakfast  calories_chicken  calories_day  \
# count  120.000000  125.000000  125.000000        125.000000    106.000000
# mean     3.415558    1.392000    1.112000        577.320000      3.028302
# std      0.390139    0.490161    0.316636        131.214156      0.639308
# min      2.200000    1.000000    1.000000        265.000000      2.000000
# 25%      3.200000    1.000000    1.000000        430.000000      3.000000
# 50%      3.500000    1.000000    1.000000        610.000000      3.000000
# 75%      3.700000    2.000000    1.000000        720.000000      3.000000
# max      4.000000    2.000000    2.000000        720.000000      4.000000
#
#        calories_scone     coffee  comfort_food_reasons_coded        cook  \
# count      124.000000  125.00000                  106.000000  122.000000
# mean       505.241935    1.75200                    2.698113    2.786885
# std        230.840506    0.43359                    1.972042    1.038351
# min        315.000000    1.00000                    1.000000    1.000000
# 25%        420.000000    2.00000                    2.000000    2.000000
# 50%        420.000000    2.00000                    2.000000    3.000000
# 75%        420.000000    2.00000                    3.000000    3.000000
# max        980.000000    2.00000                    9.000000    5.000000
#
#        comfort_food_reasons_coded.1  ...  self_perception_weight        soup  \
# count                    125.000000  ...              124.000000  124.000000
# mean                       2.688000  ...                3.120968    1.217742
# std                        1.910987  ...                1.115980    0.414385
# min                        1.000000  ...                1.000000    1.000000
# 25%                        2.000000  ...                2.000000    1.000000
# 50%                        2.000000  ...                3.000000    1.000000
# 75%                        3.000000  ...                4.000000    1.000000
# max                        9.000000  ...                6.000000    2.000000
#
#            sports   thai_food  tortilla_calories  turkey_calories  \
# count  123.000000  125.000000         124.000000       125.000000
# mean     1.390244    3.336000         947.580645       555.040000
# std      0.489800    1.436528         202.090179       152.370379
# min      1.000000    1.000000         580.000000       345.000000
# 25%      1.000000    2.000000         725.000000       500.000000
# 50%      1.000000    3.000000         940.000000       500.000000
# 75%      2.000000    5.000000        1165.000000       690.000000
# max      2.000000    5.000000        1165.000000       850.000000
#
#        veggies_day    vitamins  waffle_calories      weight
# count   125.000000  125.000000       125.000000  120.000000
# mean      4.008000    1.512000      1073.400000  158.500000
# std       1.081337    0.501867       248.667092   31.758278
# min       1.000000    1.000000       575.000000  100.000000
# 25%       3.000000    1.000000       900.000000  135.000000
# 50%       4.000000    2.000000       900.000000  155.000000
# 75%       5.000000    2.000000      1315.000000  180.000000
# max       5.000000    2.000000      1315.000000  265.000000
#
# [8 rows x 49 columns]

# %%
df['calories_day'].unique()
# Out:
# array([nan,  3.,  4.,  2.])

# %%
np.all(np.equal(df['calories_day'].dropna()%1,0))
# Out:
# np.True_

# %%
df.select_dtypes(include='number').columns
# Out:
# Index(['GPA', 'Gender', 'breakfast', 'calories_chicken', 'calories_day',
#        'calories_scone', 'coffee', 'comfort_food_reasons_coded', 'cook',
#        'comfort_food_reasons_coded.1', 'cuisine', 'diet_current_coded',
#        'drink', 'eating_changes_coded', 'eating_changes_coded1', 'eating_out',
#        'employment', 'ethnic_food', 'exercise', 'father_education',
#        'fav_cuisine_coded', 'fav_food', 'fries', 'fruit_day', 'grade_level',
#        'greek_food', 'healthy_feeling', 'ideal_diet_coded', 'income',
#        'indian_food', 'italian_food', 'life_rewarding', 'marital_status',
#        'mother_education', 'nutritional_check', 'on_off_campus',
#        'parents_cook', 'pay_meal_out', 'persian_food',
#        'self_perception_weight', 'soup', 'sports', 'thai_food',
#        'tortilla_calories', 'turkey_calories', 'veggies_day', 'vitamins',
#        'waffle_calories', 'weight'],
#       dtype='object')

# %%
for col in df.select_dtypes(include='number').columns:
    if np.all(np.equal(df[col].dropna()%1,0)):
        avg=round(df[col].mean())
        df[col]=df[col].fillna(avg)
    else:
        avg=df[col].mean()
        df[col]=df[col].fillna(avg)

# %%
for col in df.columns:
    na=df[col].isna().sum()
    if na>0:
        print(f"{col} has {na} missing")
# Out:
# comfort_food has 1 missing
# comfort_food_reasons has 2 missing
# diet_current has 1 missing
# eating_changes has 3 missing
# father_profession has 3 missing
# fav_cuisine has 2 missing
# food_childhood has 1 missing
# healthy_meal has 1 missing
# ideal_diet has 1 missing
# meals_dinner_friend has 3 missing
# mother_profession has 2 missing
# type_sports has 26 missing

# %%
for col in df.select_dtypes(include='object').columns:
    df[col]=df[col].fillna('missing')

# %%
for col in df.columns:
    if "food" in col:
        print(col)
# Out:
# comfort_food
# comfort_food_reasons
# comfort_food_reasons_coded
# comfort_food_reasons_coded.1
# ethnic_food
# fav_food
# food_childhood
# greek_food
# indian_food
# italian_food
# persian_food
# thai_food

# %%
for col in df.columns:
    if "cal" in col:
        print(col)
# Out:
# calories_chicken
# calories_day
# calories_scone
# tortilla_calories
# turkey_calories
# waffle_calories

# %%
df['indian_food'].unique()
# Out:
# array([5, 4, 2, 1, 3])

# %%
df['italian_food'].unique()
# Out:
# array([5, 4, 3])

# %%
df['thai_food'].unique()
# Out:
# array([1, 2, 5, 4, 3])

# %%
df['greek_food'].unique()
# Out:
# array([5, 4, 2, 3, 1])

# %%
df['persian_food'].unique()
# Out:
# array([5., 4., 2., 1., 3.])

# %%
for col in df.columns:
    if 'food' in col:
        print(col)
        print(df[col].dtypes)
        print()
# Out:
# comfort_food
# object
#
# comfort_food_reasons
# object
#
# comfort_food_reasons_coded
# float64
#
# comfort_food_reasons_coded.1
# int64
#
# ethnic_food
# int64
#
# fav_food
# float64
#
# food_childhood
# object
#
# greek_food
# int64
#
# indian_food
# int64
#
# italian_food
# int64
#
# persian_food
# float64
#
# thai_food
# int64
